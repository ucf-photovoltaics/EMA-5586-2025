# %% [markdown]
# # EMA 5586 - DataCamp Assignment 4
#
# Complete each of the steps below and submit this by **March 25, 2025**.

# %%
# Loading all of necessary packages here

suppressPackageStartupMessages(library(tidyverse))

library(readr)
library(ggplot2)
library(tidyverse)
library(plyr)
library(dplyr)
library(readr)
library(scales)
library(reshape2)
install.packages("readxl")
library(readr)
library(readxl)
# Out:
# The following package(s) will be installed:
# - readxl [1.4.3]
# These packages will be installed into "~/renv/library/linux-ubuntu-jammy/R-4.4/x86_64-pc-linux-gnu".
#
# # Installing packages --------------------------------------------------------
# - Installing readxl ...                         OK [linked from cache]
# ...

# %% [markdown]
# ## Task 1
# As with DataCamp Assignment 3, let us still assume you are working as an R&D Engineer for a silicon photovoltaic (PV) cell manufacturing company, but this time you are trying to optimize the carrier-selective junction of the passivated emitter and rear cell (PERC) cells using the same plasma-enhanced chemical vapor deposition (PECVD) process to deposit a silicon nitride ($SiN_{x}$) antireflection coating (ARC) and passivation film as before.
#
# Starting with the default settings in [ENDA 2](https://www2.pvlighthouse.com.au/calculators/EDNA%202/EDNA%202.aspx) from PV Lighthouse, modify the fixed charge ($Q_{f}$) to $Q_{f} = +5 \cdot 10^{12} ~ cm^{-2}$ to match the findings from the previous assignment. Now, you will evaluate different phosphorus concentration depth profiles to understand the relationship between recombination losses observed through the saturation current density ($J_{0E}$) and lateral transport losses observed through the sheet resistance, given as $R_{sheet}$ in the class and $\rho_{sq}$ in EDNA.
#
# To accomplish this, you will complete the following steps that consist of changing the peak doping concentration ($N_{peak}$) and dopant depth ($z_{f}$) using the complementary error function (erfc) function that approximates a phosphorus diffusion profile reasonably well. These values can be modifed in an actual diffusion step by changing the time and temperature during the $POCl_{3}$ diffusion process.

# %% [markdown]
# ## Q1.1
# First, design a simulation study to evaluate the relationship between the model inputs, including:
#
# - $N_{peak}$
# - $z_{f}$
#
# and the model outputs, including:
# - $J_{0E}$
# - $R_{sheet}$ (given as $\rho_{sq}$ in EDNA)
#
# Do this by creating a spreadsheet where each columns represents the input and output parameters. Each row will then represent each combination of different inputs. Think about what type of simulation split will be for the inputs, then input them in the calculator, and record the outputs. Save this spreadsheet as a CSV file with the filename: _phosphorus_profiles_EDNA.csv_

# %% [markdown]
# ## Response to Q1.1
#
# Upload your CSV file to the _Data_Diffusion_ folder.

# %% [markdown]
# ## Q1.2
#
# Read in your CSV file and display it below by creating a _R_ code chunk in this notebook. Feel free to look at previous assignments on how this is done and copy, paste, and edit it as you see fit.

# %% [markdown]
# ## Response to Q1.2

# %% [markdown]
# ## Q1.3
#
# Create the following simple scatterplots:
#
# - $N_{peak}$ vs. $J_{0E}$
# - $N_{peak}$ vs. $R_{sheet}$ (given as $\rho_{sq}$ in EDNA)
# - $z_{f}$ vs. $J_{0E}$
# - $z_{f}$ vs. $R_{sheet}$ (given as $\rho_{sq}$ in EDNA)
# - $J_{0E}$ vs. $R_{sheet}$ (given as $\rho_{sq}$ in EDNA)
#
# Feel free to look at previous assignments on how this is done and copy, paste, and edit it as you see fit.

# %% [markdown]
# ## Response to Q1.3

# %% [markdown]
# ## Q1.4
#
# Provide an explanation of the trends observed in the various scatterplots. Remember, as a R\&D engineer, just showing results is not sufficient. Some explanation is preferred to make sense of the findings.

# %% [markdown]
# ## Response to Q1.4
#
# _Answer_

# %% [markdown]
# ## Q1.5
#
# Find a combination of $N_{peak}$ vs. $z_{f}$ that simultaneously lead to a $R_{sheet}$ less than 100 $\Omega$/sq and a $J_{0E}$ less than 30 $fA/cm^{2}$.

# %% [markdown]
# ## Response to Q1.5
# Enter your input and output values here.
#
# Inputs
# - $N_{peak}$ = ... $cm^{-3}$
# - $z_{f}$ = ... $\mu m$
#
# Outputs
# - $R_{sheet}$ = ... $\Omega$/sq
# - $J_{0E}$ = ... $fA/cm^{2}$

# %% [markdown]
# ## Task 2
#
# Now, your company is considering an alternative metallization approach for the Ag front grid contacts of the PERC cells. A new paste supplier has emerged claiming they can reduce the line width and increase the height of the Ag grid lines, although the contact resistivity goes increase some. Use the [Grid Calculator](https://www2.pvlighthouse.com.au/calculators/Grid%20calculator/Grid%20calculator.aspx) from PV Lighthouse to see if this process is better.
#
# Your current paste aligns with default settings in the Grid Calculator, but you need to modify the contact resistivity ($\rho_{c}$ in class and $R_{s contact}$ in the calculator) to 1 $m\Omega$ $cm^{2}$ (note the units here and in the calculator). This should lead to a total $R_{s}$ contribution from the front grid of 0.105 $\Omega$ $cm^{2}$ for the current paste.
#
# For the new Ag paste alternative, the company can reduce the width of the grid line fingers from 100 $\mu m$ down to 90 $\mu m$ and increase the height from 30 $\mu m$ to 50 $\mu m$. However, the contact resistivity is two times higher now. Now, answer the following questions.
#
# ## Q2.1
# What is total $R_{s}$ contribution from the front grid with this new paste?
#
# ## Q2.2
# Are there any other obvious advantages or disadvantages you would anticipate by adopting this new paste based on these metrics? You can assume it would be very easy to integrate this paste into your manufacturing line, so do not worry about added process development costs.
#
# ## Q2.3
# How would you about calculating the new efficiency of PV cells made from this alternative paste? Please consider all relevant loss mechanisms related to this specific problem and walk through each step of the process.

# %% [markdown]
# ## Response to Q2.1
# _Answer_

# %% [markdown]
# ## Response to Q2.2
# _Answer_

# %% [markdown]
# ## Response to Q2.3
# _Answer_

# %% [markdown]
# ## Task 3
#
# This task relates directly to your research report that you will have due for this class. Here, you will create your populated literature summary table using the instructions provided in the lecture on this topic, [18-Literature-Survey.pdf](https://webcourses.ucf.edu/courses/1478663/files/113302535?module_item_id=19448812).
#
# You will carry this out using the (at least) 25 peer-reviewed journal articles you found in the previous assignment (feel free to add more if you have found additional articles since then).
#
#
# ## Q3.1
# Follow the steps in the lecture included in the slide deck and add the following two CSV files to the _Documents_ folder in this workbook.
#
# 1. An Excel file based on the CVS file of the original table created by NotebookLM, with this filename.
# _LastName_FirstName_EMA_5586_Table_NotebookLM.csv_
#
# 2. The updated version based on your reading, where you have made corrections, added new entries, and rephrased things based on your reading and your chatting with NotebookLM. Use this filename
# _LastName_FirstName_EMA_5586_Table_Annotated.csv_

# %% [markdown]
# ## Response to Q3.1
#
# Confirm both of the CSV files with the proper filenames are in the _Documents_ folder of this workbook.

# %% [markdown]
# ## Submission
#
# Click the share button in this data notebook and add the instructor's email address: kristopher.davis@ucf.edu
#
# Make sure to save a copy of your notebook in a place where you can retrieve it later, if necessary. You can do this by clicking File and then Download.
